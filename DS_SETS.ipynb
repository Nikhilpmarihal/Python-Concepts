# %%
s = {10,20,30,40,50}
print(type(s))
# Out:
# <class 'set'>

# %%
#You can store only Hashable values inside set
print(hash("Hello"))
# Out:
# 1629974974457816794

# %%
s = {10,"hello",(1,2,3),12.5,True,print()}

# %%
#you cannot have duplicate values
s = {10,10,10,20,20,20,30,30,30}
print(s)
# Out:
# {10, 20, 30}

# %%
# #unordered nature
s = {10,40,50,20,60,80}
print(s[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3008544143.py in <cell line: 0>()
#       1 # #unordered nature
#       2 s = {10,40,50,20,60,80}
# ----> 3 print(s[0])
#
# TypeError: 'set' object is not subscriptable

# %%
a = [12,12,12,34,34,6,7,7,8,0,7,4,3,2]
s = set(a)
print(s)
# Out:
# {0, 34, 3, 4, 2, 6, 7, 8, 12}

# %%
#traversing on the set

s = {12,34,56,12,12,78,23}

for i in s:
  print(i)

s1 = {10,20,30,40}
s2 = {30,40,50,60}

print(s1 | s2)
# Out:
# 34
# 23
# 56
# 12
# 78
# {40, 10, 50, 20, 60, 30}
