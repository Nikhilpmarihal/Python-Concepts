# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World",2026)
# Out:
# Hello World 2026

# %%
print("""Hello world
happy new year 2026""")
# Out:
# Hello world
# happy new year 2026

# %%
print('Hello \'World\', This is XYZ .How are you?')
# Out:
# Hello 'World', This is XYZ .How are you?
