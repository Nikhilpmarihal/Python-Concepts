# %%
my_var = "Nik"
print(my_var)
# Out:
# Nik

# %%
my_var = "Nik"
x= 20
print(my_var,x)
# Out:
# Nik 20

# %%
x = 5
y = 12
print(x+y)
# Out:
# 17

# %%
x,y,z=5,10,15

# %%
x=y=z=20

# %%
total_sum = (10+20 +
             30+40+50)
print(total_sum)
# Out:
# 150

# %%
a =10
b =1.5
print(a+b)
# Out:
# 11.5
